# %%
import pandas, jaal

# %%
node_df = pandas.read_csv('nodes.csv')
node_df
# Out:
#                                     id        entity political_affiliation
# 0                       Laurel Sulfate    individual            republican
# 1                  Alejandro Von Ryker    individual                    na
# 2                           Bruce Rinz    individual                    na
# 3                           John Torch    individual              democrat
# 4                           Rex Luthor    individual            republican
# 5                    Dr Philip Boynton    individual                    na
# 6                     Delwin Sanderson    individual                    na
# 7                           Gary Locke    individual            republican
# 8                 Boynton Laboratories  organization                    na
# 9   Von Ryker Institute of Research AG  organization                    na
# 10                   Washen Foundation  organization                    na
# ...

# %%
edge_df = pandas.read_csv('edges.csv')
edge_df
# Out:
#                                   from                    to
# 0                  Alejandro Von Ryker      Delwin Sanderson
# 1                           John Torch        Laurel Sulfate
# 2                           Gary Locke            Rex Luthor
# 3                           Gary Locke     Dr Philip Boynton
# 4                    Dr Philip Boynton            Rex Luthor
# 5                       Laurel Sulfate     Dr Philip Boynton
# 6                           Rex Luthor        Laurel Sulfate
# 7   Von Ryker Institute of Research AG      Delwin Sanderson
# 8   Von Ryker Institute of Research AG   Alejandro Von Ryker
# 9                           Bruce Rinz     Washen Foundation
# 10                   Washen Foundation  Boynton Laboratories
# 11                          Gary Locke             City Hall
# 12                          Rex Luthor             City Hall
# 13                   Dr Philip Boynton             City Hall
# ...

# %%
#Hypothesis 3: The new laboratory in Alderwood is supported by City Hall and strongly connected to Von Ryker Institute of Research AG.
from jaal import Jaal

# %%
Jaal(edge_df=edge_df, node_df=node_df).plot()
# Out:
# Parsing the data...Done
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# No trigger
# inside color node entity
# No trigger
# No trigger
