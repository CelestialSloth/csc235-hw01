# %%
import pandas, jaal
# Out:
# /Users/elainedemetrion/Development/csc235/csc235env/lib/python3.10/site-packages/dash_bootstrap_components/_table.py:5: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
node_df = pandas.read_csv('nodes.csv')
node_df
# Out:
#                                                 id
# 0                                   Laurel Sulfate
# 1                                   Laurie Sulfate
# 2                              Alejandro Von Ryker
# 3                                       Bruce Rinz
# 4                                       John Torch
# 5                                       Rex Luthor
# 6                                Dr Philip Boynton
# 7                                 Delwin Sanderson
# 8                                       Gary Locke
# 9                                              FDA
# 10                            Boynton Laboratories
# 11              Von Ryker Institute of Research AG
# 12                               Washen Foundation
# 13                                       City Hall
# 14  Swiss National Surveillance and Research Board

# %%
edge_df = pandas.read_csv('edges.csv')
edge_df
# Out:
#                                from  \
# 0               Alejandro Von Ryker
# 1                    Laurie Sulfate
# 2                        John Torch
# 3                        Gary Locke
# 4                        Gary Locke
# 5                 Dr Philip Boynton
# 6                    Laurel Sulfate
# 7                        Rex Luthor
# 8   Von Ryker Institute of Research
# 9   Von Ryker Institute of Research
# 10                       Bruce Rinz
# 11                Washen Foundation
# 12                       Gary Locke
# 13                       Rex Luthor
# 14                Dr Philip Boynton
# 15                   Laurel Sulfate
# 16                Dr Philip Boynton
# 17                              FDA
# 18  Von Ryker Institute of Research
#
#                                                 to
# 0                                 Delwin Sanderson
# 1                                       Rex Luthor
# 2                                   Laurel Sulfate
# 3                                       Rex Luthor
# 4                                Dr Philip Boynton
# 5                                       Rex Luthor
# 6                                Dr Philip Boynton
# 7                                   Laurel Sulfate
# 8                                 Delwin Sanderson
# 9                              Alejandro Von Ryker
# 10                               Washen Foundation
# 11                            Boynton Laboratories
# 12                                       City Hall
# 13                                       City Hall
# 14                                       City Hall
# 15                            Boynton Laboratories
# 16                            Boynton Laboratories
# 17                            Boynton Laboratories
# 18  Swiss National Surveillance and Research Board

# %%
from jaal import Jaal

# %%
Jaal(edge_df=edge_df, node_df=node_df).plot()
# Out:
# Parsing the data...Done
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# No trigger
