# %%
import pandas, numpy

# %%
phone_logs_df = pandas.read_csv('hw01-data-cleaned/conference_room_phone_logs.csv')
phone_logs_df.head()
# Out:
#          DATE    TIME   NUMBER CALLED                               TYPE  \
# 0  01/04/2002  Friday  (509) 575-3571                          Probation
# 1  01/04/2002  Friday  (509) 575-6091         Human Services (Personnel)
# 2  01/04/2002  Friday  (509) 575-6184                      City Attorney
# 3  01/04/2002  Friday  (509) 965-2405  Private Alderwood Phone Number 20
# 4  01/04/2002  Friday  (509) 965-2405  Private Alderwood Phone Number 20
#
#    red text?
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
voter_registry_df = pandas.read_csv('hw01-data-cleaned/voter_registry.csv')
voter_registry_df.head()
# Out:
#   LAST NAME FIRST NAME         DOB           POB          SSN     SEX  \
# 0     SMITH       Alex  01/05/1917     Alderwood  970-18-7974    MALE
# 1   JOHNSON     Bonnie  01/07/1916     Alderwood  228-59-7899  FEMALE
# 2  WILLIAMS    Charley  02/07/1913          Utah  176-01-4411    MALE
# 3     JONES   Danielle  11/05/1915     Alderwood  624-29-3132  FEMALE
# 4     BROWN       Earl  01/10/1916  PENNSYLVANIA  882-79-8502    MALE
#
#    STREET NUMBER STREET NAME VOTER REG DATE      PARTY
# 0         1355.0      ANGORA     01/01/1935    DEMOCRAT
# 1         1773.0      SECOND     01/02/1935    DEMOCRAT
# 2          155.0    BRITTANY     01/03/1935    DEMOCRAT
# 3           13.0      COLLIE     01/04/1935    DEMOCRAT
# 4          671.0     SAGUARO     01/05/1935  REPUBLICAN
